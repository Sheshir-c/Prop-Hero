# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:/Users/User/Desktop/DATA/Final Project/1_rent_m2.xlsx')

# %%
df.columns
# Out:
# Index(['Country_Code', 'Country Name', 'Autonomus_Community_Code',
#        'Autonomus_Community_Name', 'Province_Code', 'Province_Name',
#        'Town_code', 'Town_name', 'Max Price', 'Max month', 'Unnamed: 10',
#        '2023Q4', '2023Q3', '2023Q2', '2023Q1', '2022Q4', '2022Q3', '2022Q2',
#        '2022Q1', '2021Q4', '2021Q3', '2021Q2', '2021Q1', '2020Q4', '2020Q3',
#        '2020Q2', '2020Q1', '2019Q4', '2019Q3', '2019Q2', '2019Q1', '2018Q4',
#        '2018Q3', '2018Q2', '2018Q1', '2017Q4', '2017Q3', '2017Q2', '2017Q1',
#        '2016Q4', '2016Q3', '2016Q2', '2016Q1', '2015Q4', '2015Q3', '2015Q2',
#        '2015Q1', '2014Q4', '2014Q3', '2014Q2', '2014Q1', '2013Q4', '2013Q3',
#        '2013Q2', '2013Q1', '2012Q4', '2012Q3', '2012Q2', '2012Q1', '2011Q4',
#        '2011Q3', '2011Q2', '2011Q1', '2010Q4', '2010Q3', '2010Q2', '2010Q1',
#        '2009Q4', '2009Q3', '2009Q2', '2009Q1', '2008Q4', '2008Q3', '2008Q2',
# ...

# %%
sqm = df[['Country_Code', 'Country Name', 'Autonomus_Community_Code', 'Autonomus_Community_Name', 'Province_Code', 'Province_Name', 'Town_name']]

sqm
# Out:
#      Country_Code Country Name  Autonomus_Community_Code  \
# 0              ES       España                        16
# 1              ES       España                        16
# 2              ES       España                        16
# 3              ES       España                        16
# 4              ES       España                        16
# ...           ...          ...                       ...
# 8182           ES       España                        18
# 8183           ES       España                        19
# 8184           ES       España                         1
# 8185           ES       España                         9
# 8186           ES       España                         9
#
#      Autonomus_Community_Name  Province_Code Province_Name  \
# 0                  País Vasco              1         Álava
# 1                  País Vasco              1         Álava
# 2                  País Vasco              1         Álava
# ...

# %%
df2 = df[['2023Q4', '2023Q3', '2023Q2', '2023Q1', '2022Q4', '2022Q3', '2022Q2',
       '2022Q1', '2021Q4', '2021Q3', '2021Q2', '2021Q1', '2020Q4', '2020Q3',
       '2020Q2', '2020Q1', '2019Q4', '2019Q3', '2019Q2', '2019Q1', '2018Q4',
       '2018Q3', '2018Q2', '2018Q1', '2017Q4', '2017Q3', '2017Q2', '2017Q1',
       '2016Q4', '2016Q3', '2016Q2', '2016Q1', '2015Q4', '2015Q3', '2015Q2',
       '2015Q1', '2014Q4', '2014Q3', '2014Q2', '2014Q1', '2013Q4', '2013Q3',
       '2013Q2', '2013Q1', '2012Q4', '2012Q3', '2012Q2', '2012Q1', '2011Q4',
       '2011Q3', '2011Q2', '2011Q1', '2010Q4', '2010Q3', '2010Q2', '2010Q1',
       '2009Q4', '2009Q3', '2009Q2', '2009Q1', '2008Q4', '2008Q3', '2008Q2',
       '2008Q1', '2007Q4', '2007Q3', '2007Q2', '2007Q1', '2006Q4', '2006Q3',
       '2006Q2', '2006Q1', '2005Q4', '2005Q3', '2005Q2', '2005Q1']]

df2
# Out:
#         2023Q4    2023Q3    2023Q2    2023Q1    2022Q4    2022Q3    2022Q2  \
# 0     1417.075  1417.075  1118.825  1118.825  1178.050  1059.600  1118.825
# 1     1109.125  1006.000   947.575   966.670   939.760   949.370  1021.460
# 2      525.760   651.520   383.335   416.670   416.670   729.795   810.295
# 3     1194.610  1171.110  1130.430   971.015   971.015   905.470   905.470
# 4      945.955   945.955   997.610  1101.120   969.200   968.470   884.580
# ...        ...       ...       ...       ...       ...       ...       ...
# 8182  2222.220  2209.260  2245.100  2272.730  2098.755  2033.330  1881.190
# 8183  2000.000  1936.090  1952.535  1895.645  1938.780  1929.820  1941.255
# 8184  1283.260  1181.820  1172.840  1172.840  1172.840  1277.660  1504.810
# 8185  1034.165  1008.330  1071.430  1072.035  1025.290  1000.000   885.520
# 8186  1782.410  1266.140  1467.950  1769.230  1735.525  1769.230  1403.305
#
# ...

# %%
# Function to convert column name from 'YYYYQX' to 'YYYY-MM'
def convert_column_name(column_name):
    year, quarter = column_name.split('Q')
    year_month = f"{year}-{(int(quarter) - 1) * 3 + 1:02d}"
    return year_month

# Rename columns
df2.columns = [convert_column_name(column) for column in df2.columns]

# %%
df2.columns
# Out:
# Index(['2023-10', '2023-07', '2023-04', '2023-01', '2022-10', '2022-07',
#        '2022-04', '2022-01', '2021-10', '2021-07', '2021-04', '2021-01',
#        '2020-10', '2020-07', '2020-04', '2020-01', '2019-10', '2019-07',
#        '2019-04', '2019-01', '2018-10', '2018-07', '2018-04', '2018-01',
#        '2017-10', '2017-07', '2017-04', '2017-01', '2016-10', '2016-07',
#        '2016-04', '2016-01', '2015-10', '2015-07', '2015-04', '2015-01',
#        '2014-10', '2014-07', '2014-04', '2014-01', '2013-10', '2013-07',
#        '2013-04', '2013-01', '2012-10', '2012-07', '2012-04', '2012-01',
#        '2011-10', '2011-07', '2011-04', '2011-01', '2010-10', '2010-07',
#        '2010-04', '2010-01', '2009-10', '2009-07', '2009-04', '2009-01',
#        '2008-10', '2008-07', '2008-04', '2008-01', '2007-10', '2007-07',
#        '2007-04', '2007-01', '2006-10', '2006-07', '2006-04', '2006-01',
#        '2005-10', '2005-07', '2005-04', '2005-01'],
#       dtype='object')

# %%
year = df2

data = pd.concat([sqm, year], axis=1)

data.drop(columns=['Country_Code', 'Country Name'], inplace=True)

data
# Out:
#       Autonomus_Community_Code Autonomus_Community_Name  Province_Code  \
# 0                           16               País Vasco              1
# 1                           16               País Vasco              1
# 2                           16               País Vasco              1
# 3                           16               País Vasco              1
# 4                           16               País Vasco              1
# ...                        ...                      ...            ...
# 8182                        18                    Ceuta             51
# 8183                        19                  Melilla             52
# 8184                         1                Andalucía             29
# 8185                         9                 Cataluña             43
# 8186                         9                 Cataluña             17
#
#      Province_Name                                    Town_name   2023-10  \
# ...

# %%
df2.replace(0, np.nan, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6516\2028158365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace(0, np.nan, inplace=True)

# %%
data = data.groupby('Autonomus_Community_Name')[['2023-10', '2023-07', '2023-04', '2023-01', '2022-10', '2022-07',
       '2022-04', '2022-01', '2021-10', '2021-07', '2021-04', '2021-01',
       '2020-10', '2020-07', '2020-04', '2020-01', '2019-10', '2019-07',
       '2019-04', '2019-01', '2018-10', '2018-07', '2018-04', '2018-01',
       '2017-10', '2017-07', '2017-04', '2017-01', '2016-10', '2016-07',
       '2016-04', '2016-01', '2015-10', '2015-07', '2015-04', '2015-01',
       '2014-10', '2014-07', '2014-04', '2014-01', '2013-10', '2013-07',
       '2013-04', '2013-01', '2012-10', '2012-07', '2012-04', '2012-01',
       '2011-10', '2011-07', '2011-04', '2011-01', '2010-10', '2010-07',
       '2010-04', '2010-01', '2009-10', '2009-07', '2009-04', '2009-01',
       '2008-10', '2008-07', '2008-04', '2008-01', '2007-10', '2007-07',
       '2007-04', '2007-01', '2006-10', '2006-07', '2006-04', '2006-01',
       '2005-10', '2005-07', '2005-04', '2005-01']].mean()

# %%
data
# Out:
#                                 2023-10      2023-07      2023-04  \
# Autonomus_Community_Name
# Andalucía                    894.999254   879.563437   894.730363
# Aragón                       509.590663   512.200609   521.749063
# Canarias                    1696.132386  1669.082841  1650.657784
# Cantabria                   1029.593235  1028.914069  1040.783088
# Castilla - La Mancha         525.037824   513.416926   533.016578
# Castilla y León              450.781041   447.328961   462.223972
# Cataluña                    1314.182482  1299.385143  1336.831806
# Ceuta                       2222.220000  2209.260000  2245.100000
# Comunidad Foral de Navarra   712.621531   722.535525   755.055525
# Comunidad Valenciana         929.205231   924.678183   930.623736
# Comunidad de Madrid         1554.664888  1535.171620  1573.622095
# Extremadura                  533.290104   515.074195   539.144532
# Galicia                      780.761587   770.947651   797.177238
# ...

# %%
data
# Out:
#                                 2023-10      2023-07      2023-04  \
# Autonomus_Community_Name
# Andalucía                    894.999254   879.563437   894.730363
# Aragón                       509.590663   512.200609   521.749063
# Canarias                    1696.132386  1669.082841  1650.657784
# Cantabria                   1029.593235  1028.914069  1040.783088
# Castilla - La Mancha         525.037824   513.416926   533.016578
# Castilla y León              450.781041   447.328961   462.223972
# Cataluña                    1314.182482  1299.385143  1336.831806
# Ceuta                       2222.220000  2209.260000  2245.100000
# Comunidad Foral de Navarra   712.621531   722.535525   755.055525
# Comunidad Valenciana         929.205231   924.678183   930.623736
# Comunidad de Madrid         1554.664888  1535.171620  1573.622095
# Extremadura                  533.290104   515.074195   539.144532
# Galicia                      780.761587   770.947651   797.177238
# ...

# %%
""" data['Town/Province'] = data['Town_name'].str.cat(data['Province_Name'], sep='-') """
# Out:
# " data['Town/Province'] = data['Town_name'].str.cat(data['Province_Name'], sep='-') "

# %%
""" data.drop(columns=['Autonomus_Community_Code', 'Autonomus_Community_Name', 'Province_Code',
       'Province_Name', 'Town_name'], inplace=True) """
# Out:
# " data.drop(columns=['Autonomus_Community_Code', 'Autonomus_Community_Name', 'Province_Code',\n       'Province_Name', 'Town_name'], inplace=True) "

# %%
""" data.set_index('Town/Province', inplace=True) """
# Out:
# " data.set_index('Town/Province', inplace=True) "

# %%
""" data.reset_index() """
# Out:
# ' data.reset_index() '

# %%
df2 = data.T

df2
# Out:
# Autonomus_Community_Name   Andalucía      Aragón     Canarias    Cantabria  \
# 2023-10                   894.999254  509.590663  1696.132386  1029.593235
# 2023-07                   879.563437  512.200609  1669.082841  1028.914069
# 2023-04                   894.730363  521.749063  1650.657784  1040.783088
# 2023-01                   882.365571  542.626183  1620.896534  1032.690833
# 2022-10                   868.108035  526.221122  1599.255455  1012.990392
# ...                              ...         ...          ...          ...
# 2006-01                   658.652594  390.135431  1424.184545  1131.617745
# 2005-10                   671.217069  326.280205  1419.857386  1100.398529
# 2005-07                   662.540713  318.495896  1372.267500  1067.224608
# 2005-04                   651.902827  315.691382  1355.123750  1063.477255
# 2005-01                   633.298975  300.918741   725.880114  1024.987843
#
# ...

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
# Autonomus_Community_Name    index   Andalucía      Aragón     Canarias  \
# 0                         2023-10  894.999254  509.590663  1696.132386
# 1                         2023-07  879.563437  512.200609  1669.082841
# 2                         2023-04  894.730363  521.749063  1650.657784
# 3                         2023-01  882.365571  542.626183  1620.896534
# 4                         2022-10  868.108035  526.221122  1599.255455
# ..                            ...         ...         ...          ...
# 71                        2006-01  658.652594  390.135431  1424.184545
# 72                        2005-10  671.217069  326.280205  1419.857386
# 73                        2005-07  662.540713  318.495896  1372.267500
# 74                        2005-04  651.902827  315.691382  1355.123750
# 75                        2005-01  633.298975  300.918741   725.880114
#
# Autonomus_Community_Name    Cantabria  Castilla - La Mancha  Castilla y León  \
# ...

# %%
df2.sort_values(by='index', ascending=False)
# Out:
# Autonomus_Community_Name    index   Andalucía      Aragón     Canarias  \
# 0                         2023-10  894.999254  509.590663  1696.132386
# 1                         2023-07  879.563437  512.200609  1669.082841
# 2                         2023-04  894.730363  521.749063  1650.657784
# 3                         2023-01  882.365571  542.626183  1620.896534
# 4                         2022-10  868.108035  526.221122  1599.255455
# ..                            ...         ...         ...          ...
# 71                        2006-01  658.652594  390.135431  1424.184545
# 72                        2005-10  671.217069  326.280205  1419.857386
# 73                        2005-07  662.540713  318.495896  1372.267500
# 74                        2005-04  651.902827  315.691382  1355.123750
# 75                        2005-01  633.298975  300.918741   725.880114
#
# Autonomus_Community_Name    Cantabria  Castilla - La Mancha  Castilla y León  \
# ...

# %%
df2.replace(0, np.nan, inplace=True)

# %%
df2.columns
# Out:
# Index(['index', 'Andalucía', 'Aragón', 'Canarias', 'Cantabria',
#        'Castilla - La Mancha', 'Castilla y León', 'Cataluña', 'Ceuta',
#        'Comunidad Foral de Navarra', 'Comunidad Valenciana',
#        'Comunidad de Madrid', 'Extremadura', 'Galicia', 'Islas Baleares',
#        'La Rioja', 'Melilla', 'País Vasco', 'Principado de Asturias',
#        'Región de Murcia'],
#       dtype='object', name='Autonomus_Community_Name')

# %%
for column in df2.columns:
    if df2[column].iloc[:-10].isna().sum() > 10:
        df2.drop(columns=[column], inplace=True)

# %%
df2
# Out:
# Autonomus_Community_Name    index   Andalucía      Aragón     Canarias  \
# 0                         2023-10  894.999254  509.590663  1696.132386
# 1                         2023-07  879.563437  512.200609  1669.082841
# 2                         2023-04  894.730363  521.749063  1650.657784
# 3                         2023-01  882.365571  542.626183  1620.896534
# 4                         2022-10  868.108035  526.221122  1599.255455
# ..                            ...         ...         ...          ...
# 71                        2006-01  658.652594  390.135431  1424.184545
# 72                        2005-10  671.217069  326.280205  1419.857386
# 73                        2005-07  662.540713  318.495896  1372.267500
# 74                        2005-04  651.902827  315.691382  1355.123750
# 75                        2005-01  633.298975  300.918741   725.880114
#
# Autonomus_Community_Name    Cantabria  Castilla - La Mancha  Castilla y León  \
# ...

# %%
df2.to_excel("rentm2_region.xlsx")

# %%
df2 = pd.read_excel('C:/Users/User/Desktop/DATA/Final Project/Final Dataset/1_prixm2_region.xlsx')

# %%
df2
# Out:
#       index   Andalucía      Aragón     Canarias    Cantabria  \
# 0   2023-10  894.999254  509.590663  1696.132386  1029.593235
# 1   2023-07  879.563437  512.200609  1669.082841  1028.914069
# 2   2023-04  894.730363  521.749063  1650.657784  1040.783088
# 3   2023-01  882.365571  542.626183  1620.896534  1032.690833
# 4   2022-10  868.108035  526.221122  1599.255455  1012.990392
# ..      ...         ...         ...          ...          ...
# 71  2006-01  658.652594  390.135431  1424.184545  1131.617745
# 72  2005-10  671.217069  326.280205  1419.857386  1100.398529
# 73  2005-07  662.540713  318.495896  1372.267500  1067.224608
# 74  2005-04  651.902827  315.691382  1355.123750  1063.477255
# 75  2005-01  633.298975  300.918741  1355.123750  1024.987843
#
#     Castilla - La Mancha  Castilla y León     Cataluña  \
# 0             525.037824       450.781041  1314.182482
# 1             513.416926       447.328961  1299.385143
# ...

# %%
caillou = ['Andalucía', 'Aragón', 'Canarias', 'Cantabria',
       'Castilla - La Mancha', 'Castilla y León', 'Cataluña',
       'Comunidad Foral de Navarra', 'Comunidad Valenciana',
       'Comunidad de Madrid', 'Extremadura', 'Galicia', 'Islas Baleares',
       'La Rioja', 'País Vasco', 'Principado de Asturias', 'Región de Murcia']

# %%
df2[caillou].dtypes
# Out:
# Andalucía                     float64
# Aragón                        float64
# Canarias                      float64
# Cantabria                     float64
# Castilla - La Mancha          float64
# Castilla y León               float64
# Cataluña                      float64
# Comunidad Foral de Navarra    float64
# Comunidad Valenciana          float64
# Comunidad de Madrid           float64
# Extremadura                   float64
# Galicia                       float64
# Islas Baleares                float64
# La Rioja                      float64
# País Vasco                    float64
# Principado de Asturias        float64
# Región de Murcia              float64
# dtype: object

# %%
df2[["Andalucía", "Extremadura", "País Vasco"]].plot(figsize=(20, 15))
# Out:
# <Axes: >

# %%
df2["País Vasco"] = df2["País Vasco"].ffill()

# %%
df2["País Vasco"]
# Out:
# 0     1800.220259
# 1     1792.418865
# 2     1845.785777
# 3     1852.134522
# 4     1802.007331
#          ...
# 71    1904.330279
# 72    1843.064622
# 73    1819.892550
# 74    1752.530159
# 75     719.060438
# Name: País Vasco, Length: 76, dtype: float64

# %%
df2["País Vasco"] = df2["País Vasco"].replace({719.06043825: 1719.06043825})

# %%
df2["País Vasco"].tail(1).values
# Out:
# array([719.06043825])

# %%
df2.loc[df2["País Vasco"] == 719.06043825, "País Vasco"] = 1719.06043825

# %%
for x in df2["País Vasco"]:
    if x == 719.06043825:
        x.fill(1719.06043825)
    else:
        continue

df2["País Vasco"].values
# Out:
# array([1800.22025896, 1792.41886454, 1845.78577689, 1852.13452191,
#        1802.00733068, 1855.16683267, 1827.08948207, 1772.18131474,
#        1797.35772908, 1797.75749004, 1766.51482072, 1759.22047809,
#        1725.77049801, 1717.26304781, 1716.53466135, 1597.40599602,
#        1641.46418327, 1674.93687251, 1569.19252988, 1580.51436255,
#        1544.28342629, 1444.76187251, 1417.98681275, 1517.50701195,
#        1457.26474104, 1393.16665339, 1470.30434263, 1460.84625498,
#        1456.08776892, 1467.98804781, 1495.20474104, 1376.21207171,
#        1376.21207171, 1409.42430279, 1417.33844622, 1427.56354582,
#        1442.57310757, 1461.01585657, 1471.82051793, 1496.28203187,
#        1525.15557769, 1551.2374502 , 1570.70366534, 1615.79581673,
#        1650.94721116, 1698.9459761 , 1735.52940239, 1775.75884462,
#        1817.93577689, 1840.36940239, 1847.53816733, 1878.25310757,
#        1898.74139442, 1828.90095618, 1838.05792829, 1847.41358566,
# ...

# %%
cc_array = np.array([1800.22025896, 1792.41886454, 1845.78577689, 1852.13452191,
       1802.00733068, 1855.16683267, 1827.08948207, 1772.18131474,
       1797.35772908, 1797.75749004, 1766.51482072, 1759.22047809,
       1725.77049801, 1717.26304781, 1716.53466135, 1597.40599602,
       1641.46418327, 1674.93687251, 1569.19252988, 1580.51436255,
       1544.28342629, 1444.76187251, 1417.98681275, 1517.50701195,
       1457.26474104, 1393.16665339, 1470.30434263, 1460.84625498,
       1456.08776892, 1467.98804781, 1495.20474104, 1376.21207171,
       1376.21207171, 1409.42430279, 1417.33844622, 1427.56354582,
       1442.57310757, 1461.01585657, 1471.82051793, 1496.28203187,
       1525.15557769, 1551.2374502 , 1570.70366534, 1615.79581673,
       1650.94721116, 1698.9459761 , 1735.52940239, 1775.75884462,
       1817.93577689, 1840.36940239, 1847.53816733, 1878.25310757,
       1898.74139442, 1828.90095618, 1838.05792829, 1847.41358566,
       1852.88609562, 1868.26191235, 1893.02442231, 1900.6676494 ,
       1915.0663745 , 1892.5161753 , 1900.31159363, 1937.25976096,
       1956.5274502 , 1841.30657371, 1864.52713147, 1865.42410359,
       1876.74501992, 1896.11645418, 1926.72450199, 1904.33027888,
       1843.06462151, 1819.8925498 , 1752.53015936,  1719.06043825])

cc = pd.Series(cc_array)

# %%
df2["País Vasco"] = cc

# %%
df2
# Out:
#       index   Andalucía      Aragón     Canarias    Cantabria  \
# 0   2023-10  894.999254  509.590663  1696.132386  1029.593235
# 1   2023-07  879.563437  512.200609  1669.082841  1028.914069
# 2   2023-04  894.730363  521.749063  1650.657784  1040.783088
# 3   2023-01  882.365571  542.626183  1620.896534  1032.690833
# 4   2022-10  868.108035  526.221122  1599.255455  1012.990392
# ..      ...         ...         ...          ...          ...
# 71  2006-01  658.652594  390.135431  1424.184545  1131.617745
# 72  2005-10  671.217069  326.280205  1419.857386  1100.398529
# 73  2005-07  662.540713  318.495896  1372.267500  1067.224608
# 74  2005-04  651.902827  315.691382  1355.123750  1063.477255
# 75  2005-01  633.298975  300.918741  1355.123750  1024.987843
#
#     Castilla - La Mancha  Castilla y León     Cataluña  \
# 0             525.037824       450.781041  1314.182482
# 1             513.416926       447.328961  1299.385143
# ...

# %%
df2[caillou].plot(subplots=True, layout=(6, 3), figsize=(15, 15), sharex=True, sharey=True, legend=False, title=caillou)
plt.show()

# %%
df2.sort_index(inplace=True)

# %%
df2.columns
# Out:
# Index(['index', 'Andalucía', 'Aragón', 'Canarias', 'Cantabria',
#        'Castilla - La Mancha', 'Castilla y León', 'Cataluña',
#        'Comunidad Foral de Navarra', 'Comunidad Valenciana',
#        'Comunidad de Madrid', 'Extremadura', 'Galicia', 'Islas Baleares',
#        'La Rioja', 'País Vasco', 'Principado de Asturias', 'Región de Murcia'],
#       dtype='object')

# %%
df2.sort_values(by='index')
# Out:
#       index   Andalucía      Aragón     Canarias    Cantabria  \
# 75  2005-01  633.298975  300.918741  1355.123750  1024.987843
# 74  2005-04  651.902827  315.691382  1355.123750  1063.477255
# 73  2005-07  662.540713  318.495896  1372.267500  1067.224608
# 72  2005-10  671.217069  326.280205  1419.857386  1100.398529
# 71  2006-01  658.652594  390.135431  1424.184545  1131.617745
# ..      ...         ...         ...          ...          ...
# 4   2022-10  868.108035  526.221122  1599.255455  1012.990392
# 3   2023-01  882.365571  542.626183  1620.896534  1032.690833
# 2   2023-04  894.730363  521.749063  1650.657784  1040.783088
# 1   2023-07  879.563437  512.200609  1669.082841  1028.914069
# 0   2023-10  894.999254  509.590663  1696.132386  1029.593235
#
#     Castilla - La Mancha  Castilla y León     Cataluña  \
# 75            267.487682        60.941299  1234.772724
# 74            277.494342       103.995770  1292.651426
# ...

# %%
var = df2[['Andalucía', 'Aragón', 'Canarias', 'Cantabria',
       'Castilla - La Mancha', 'Castilla y León', 'Cataluña',
       'Comunidad Foral de Navarra', 'Comunidad Valenciana',
       'Comunidad de Madrid', 'Extremadura', 'Galicia', 'Islas Baleares',
       'La Rioja', 'País Vasco', 'Principado de Asturias', 'Región de Murcia']].pct_change(periods=4)

# %%
var
# Out:
#     Andalucía    Aragón  Canarias  Cantabria  Castilla - La Mancha  \
# 0         NaN       NaN       NaN        NaN                   NaN
# 1         NaN       NaN       NaN        NaN                   NaN
# 2         NaN       NaN       NaN        NaN                   NaN
# 3         NaN       NaN       NaN        NaN                   NaN
# 4   -0.030046  0.032635 -0.057116  -0.016126             -0.014776
# ..        ...       ...       ...        ...                   ...
# 71  -0.184026 -0.022146 -0.059795  -0.108477             -0.303051
# 72  -0.139551 -0.162146 -0.036336  -0.125791             -0.203212
# 73  -0.077885 -0.219685 -0.096053  -0.166764             -0.174018
# 74  -0.055181 -0.212825 -0.085627  -0.123239             -0.156778
# 75  -0.038493 -0.228681 -0.048491  -0.094228             -0.189709
#
#     Castilla y León  Cataluña  Comunidad Foral de Navarra  \
# 0               NaN       NaN                         NaN
# ...

# %%
var.dropna(inplace=True)

# %%
var.to_excel('variacion_region_prixm2.xlsx')

# %%
""" list_columns = ['Andalucia', 'Aragón', 'Canarias', 'Cantabria',
       'Castilla - La Mancha', 'Castilla y León', 'Cataluña',
       'Comunidad Foral de Navarra', 'Comunidad Valenciana',
       'Comunidad de Madrid', 'Extremadura', 'Galicia', 'Islas Baleares',
       'La Rioja', 'País Vasco', 'Principado de Asturias', 'Región de Murcia']

# Create an empty DataFrame to store percentage changes
percentage_changes_df = pd.DataFrame()
# Calculate percentage changes for each column and store in the new DataFrame
for column in list_columns:
    percentage_changes_df[column + ' var_T_%'] = sqm[column].pct_change() """

# %%
corr = var.corr()

# %%
corr
# Out:
#                             Andalucía    Aragón  Canarias  Cantabria  \
# Andalucía                    1.000000  0.713199  0.728976   0.752364
# Aragón                       0.713199  1.000000  0.564305   0.661803
# Canarias                     0.728976  0.564305  1.000000   0.722216
# Cantabria                    0.752364  0.661803  0.722216   1.000000
# Castilla - La Mancha         0.878378  0.828606  0.579176   0.687057
# Castilla y León              0.648494  0.861077  0.489902   0.681034
# Cataluña                     0.831202  0.869866  0.755503   0.771054
# Comunidad Foral de Navarra   0.420003  0.516543  0.295118   0.354640
# Comunidad Valenciana         0.887594  0.803836  0.765166   0.851294
# Comunidad de Madrid          0.689063  0.786145  0.749399   0.667494
# Extremadura                  0.672570  0.774867  0.415136   0.619772
# Galicia                      0.675724  0.623297  0.524105   0.829963
# Islas Baleares               0.510340  0.406102  0.668895   0.560524
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(corr.corr(), annot=True, cmap="magma", fmt=".1%")
plt.show()

# %%
var.columns
# Out:
# Index(['Andalucía', 'Aragón', 'Canarias', 'Cantabria', 'Castilla - La Mancha',
#        'Castilla y León', 'Cataluña', 'Comunidad Foral de Navarra',
#        'Comunidad Valenciana', 'Comunidad de Madrid', 'Extremadura', 'Galicia',
#        'Islas Baleares', 'La Rioja', 'País Vasco', 'Principado de Asturias',
#        'Región de Murcia'],
#       dtype='object')

# %%
var['Canarias'].describe()
# Out:
# count    72.000000
# mean     -0.008625
# std       0.059646
# min      -0.112980
# 25%      -0.052133
# 50%      -0.025169
# 75%       0.035128
# max       0.133525
# Name: Canarias, dtype: float64

# %%
var['Comunidad Foral de Navarra'].describe()
# Out:
# count    72.000000
# mean      0.010324
# std       0.188768
# min      -0.584592
# 25%      -0.056412
# 50%       0.021902
# 75%       0.085528
# max       1.209767
# Name: Comunidad Foral de Navarra, dtype: float64

# %%
var['Comunidad Valenciana'].describe()
# Out:
# count    72.000000
# mean     -0.007476
# std       0.076970
# min      -0.167345
# 25%      -0.063532
# 50%      -0.005523
# 75%       0.055803
# max       0.139122
# Name: Comunidad Valenciana, dtype: float64

# %%
df2.to_excel('housingtransactions.xlsx')
