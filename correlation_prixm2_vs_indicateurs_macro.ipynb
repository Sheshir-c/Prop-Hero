# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:/Users/User/Desktop/DATA/Final Project/Final Dataset/indicateurs_macro_nationaux_var_ann.xlsx')

# %%
df.drop(columns='ipc_loyer_%', inplace=True)

# %%
df
# Out:
#          Date  prix_m2_var_ann  indice_prix_logement_var_ann  \
# 0  2024-01-01         0.063200                      0.068115
# 1  2023-10-01         0.067298                      0.059182
# 2  2023-07-01         0.081725                      0.035154
# 3  2023-04-01         0.103627                      0.034368
# 4  2023-01-01         0.095914                      0.016784
# ..        ...              ...                           ...
# 68 2007-01-01         0.075752                      0.015090
# 69 2006-10-01         0.081702                      0.132370
# 70 2006-07-01         0.103533                      0.142375
# 71 2006-04-01         0.115687                      0.161988
# 72 2006-01-01         0.113313                      0.205543
#
#     nb_transaction_var_ann  licitacion_m2_var_ann  Taux interet  \
# 0                 0.011471              -0.033461      1.900000
# 1                -0.138836              -0.060658      2.033333
# ...

# %%
df.corr()
# Out:
#                                   Date  prix_m2_var_ann  \
# Date                          1.000000         0.381657
# prix_m2_var_ann               0.381657         1.000000
# indice_prix_logement_var_ann  0.112526         0.825677
# nb_transaction_var_ann        0.529662         0.107275
# licitacion_m2_var_ann         0.434778         0.571044
# Taux interet                 -0.484002         0.280561
# ipc_cout_vie_var_ann         -0.025254        -0.566890
# Consumer Confidence           0.308456         0.528454
# Industrial_Prod_new_orders    0.328060         0.662686
# business_confidence           0.366290         0.690394
# business_new_orders           0.315016         0.751405
# PIB_SPAIN                     0.171336         0.578886
#
#                               indice_prix_logement_var_ann  \
# Date                                              0.112526
# prix_m2_var_ann                                   0.825677
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(), annot=True, cmap="magma", fmt=".1%")
plt.show()
